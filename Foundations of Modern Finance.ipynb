# %% [markdown]
# # INTRODUCTION
#
# ### Motivation
#
# How to make a business decision (to create wealth)?
#
# ### What is Finance
#
# Finance is about the bottom line of business activities. A business activity is a process of acquiring and disposing **assets**: which could be real/financial, or tangible/intangible. And all business activities reduce to two functions:
# 1. Grow wealth (create value),
# 2. Manage wealth to best meet economic needs.
#
# Therefore, financially, a business decision starts with the **valuation of** assets. In short, **valuation** is the central issue of finance/business.
#
# The main questions that we will tackle here are by building a unified framework for financial analysis are as follows:
#
# 1. How to value assets?
# 2. How to make financial decisions? *capital budgeting * financing * payout * risk management
#
#
# ## A Unified Framework for financial analysis
#
# Evolution of a blanace sheet happens in accordance with the following equality.
#
# |  Assets | Liabilities  |
# |:-:|---|
# | Cash  |  Debt (D * $\delta$ D) |
# |  Capital + I | Equity (E * $\delta$ E)   |
# |  Intangibles | Intangbles  |
#
# And additionally, the framework for a financial household is as follows:
#
# ![Screen%20Shot%202020-12-10%20at%2014.12.01.png](attachment:Screen%20Shot%202020-12-10%20at%2014.12.01.png)
#
# where (1, 2, 4, 5) require cash flow analysis, (1, 4, 5) require valuing financial assets (with 1 and 4 also requiring risk management) and (2,3) involve valuing real assets.
#
# ## Valuation of Assets
#
# > Valuation of assets = Valuation of its cash flow.
# >
# > **Time** and **risk** are the two components to take into account for cash flow valuation.
#
#
# *Q: An asset yields a risky cash flow in one year with an expected value of $1,000. How much is it  worth today? Suppose that assets/cashflows traded in the financial market with the same timing and risk offer an expected return of 10\% (e.g., stocks of similar risks, yielding an expected annual return of 10\%).*
#
# ## Arbitrage
# Arbitrage is a set of trades in the financial market such that are riskless and yet generate a payoff. In an efficient market, arbitrage opportunities should not exist. **The law of One Price** states that in the absence of arbitrage, assets with same payoff should have the same prices.
#
# ## Financial Market
# Financial market serve two central roles in the economy:
# 1. Guiding economic decisions by firms/households at the micro level.
# 2. Allocation of resourcse across different economic activities at the macro level.
#
# The key players in the financial market are :
# * Securities market- Financial assets/claims/contracts are traded
#     * Money market- short term deb securities (e.g. Treasury bills, CDs, Commercial Papers, etc.)
#     * Capital Market- Long-term securities (e.g. govt. and corporate bonds, asset-bascked securities, stocks)
#     * Derivatives- Forwards and futures, swaps, options, etc.
# * Financial Intermediaries- Own mostly financial assets (e.g. Banks, insurance companies, Mutual Funds, hedge funds, private equity funds, etc.)
# * Nonfinancial firms- Own mostly real assets.
# * Households- Own both real and financial assets
# * Govts.- Own both real and financial assets/liabilities.
#
# ### Market Imperfections/frictions
# * Transaction costs
# * Information Asymmetry
# * Taxes
#
#
# ## Unifying Principles of Finance
# P1: There is no such thing as a free lunch in the financial market.
# P2: Other things equal, individuals/agents prefer:
#     * more money to less (non-satiation)
#     * avoid risk (risk aversion)
#     * money now than later (impatience)
# P3: Financial market prices shift to equalize supply and demand.
# P4: Market imperfections are central to financial innovation.

# %% [markdown]
# # MARKET PRICES AND PRESENT VALUE
# ## State-space model for time and risk
#
# There two elements of any financial model are- time  and risk
# Consider consecutive intervals: t = $t_0$, $t_1$, ... $t_N$
#
# Each interval, say $t_0$ has multiple economic **states** $s_0$, $s_1$, ..., $s_N$, with corresponding probabilities $p_0$, $p_1$, ... $p_N$. These states and probabilities are known to all decision makers.
#
# > **State price** (Arrow-Debreau) securities are securities that pay $1 in a single state and nothingn otherwise. The state price is then the price of Arrow-Debreau claim on a given state.
#
# TODO: Show how state prices can be used to calculate current prices of stocks and expected rate of return.
#
# *Q: Suppose there are two states next year. The payoff of a share of stock and the probabilities of the states are:[(\$90, \$110); (0.4,0.6)]. The state prices for the two states are:𝜙1,𝜙2= (0.5,0.4)*
#
# *Question1.What is the stock price today?*
#
# *Question 2.What is the expected rate of return of the stock?*
#
# ## Present Value
# How much is a sure cash flow of \$1000 in one year worth now? The way we solve such a problem would be to 'discount' the future cash flow with a *risk-less* return in the market. Say, we get 2\% return by investing in safe assets, then we should discount, and thus find the present value of the cash flow by 2%.

# %%
# Discount a given <principle> by <rate> for one year
discount = lambda rate, principal: principal/(1+rate)
discount(0.02, 1000)
# Out:
# 980.3921568627451

# %% [markdown]
# In other words, \\$1000 in a year is the same as \\$980.4 right now. For instance, if you invested \\$980 in safe assets right now, you would get the a guaranteed \\$1000 year from now on. This example highlights the time-value of a cash value.
#
# ## Discount rate
# We can generalize the above example, but taking discount rate as the **opportunity cost of capital**, that is, the return offered by similar assets traded in the market. Then we can easily compare two investment at the same risk level. Ex. Which is better if `ROR` = 2%, (A) \\$10 million in 5 yrs, or (B) \\$15 million in 15 yrs.

# %%
# Discount given <principle> by <rate> for <time> periods (usually a year)
discount = lambda rate, principal, time: principal/ (1+rate)**time
('A: ', discount(0.05, 10, 5), 'B: ', discount(0.05, 15, 15))
# Out:
# ('A: ', 7.835261664684588, 'B: ', 7.215256471364549)

# %% [markdown]
# ## Future Value
# Similarly, we can also calculate the future value a current investment with a given interest rate.
# E.g. Bank pays an annual interest of 4\% on 2-year CDs and you deposit \\$10,000. What is your balance two years later?

# %%
# Future value of given <principle> by <rate> for <time> periods (usually a year)
future_value = lambda rate, principal, time: principal * (1+rate)**time
future_value(0.04, 10000, 2)
# Out:
# 10816.000000000002

# %% [markdown]
# ## Present value of Cash Flows
# Now, using the above formulae, we can calculate the net value of cash flows as well. For example, given the following strategies, which one do you thing is a better one:
# 1. Invest \\$1B now, and return \\$500M, \\$400M, and \\$300M in years 1, 2, and 3
# 2. Invest \\$200M now and next year i.e. year 1, and then receive returns of \\$300M in years 2 and years 3.

# %%
# net value of a given cash flow, given an r
# NOTE: cash flow should start at year 0
net_value_cf = lambda rate, cf: sum([p/(1+rate)**i for i, p in enumerate(cf)])
print('Strategy 1: ', end='')
print(net_value_cf(0.05, [-1000, 500, 400, 300]))
print('Strategy 2: ', end='')
print(net_value_cf(0.05, [-200, -200, 300, 300]))
# Out:
# Strategy 1: 98.15354713313889
# Strategy 2: 140.78393262066726

# %% [markdown]
# ## Nominal vs real Cash Flows and rates
# What about inflation? So far, we have ignore it, but we can easily take that into account. The non-inflation adjusted cash flow is called **nominal** cash flow, and the adjusted one is called the **real** cash flow. Inorder to find the real cash flow, we 'discount' with the inflation rate.

# %%
# caluclate inflation adjusted, i.e. real cash flow value
'At an inflaiton rate of 0.04/year, $1.04 in a year is = '+ str(discount(0.04, 1.04, 1))
# Out:
# 'At an inflaiton rate of 0.04/year, $1.04 in a year is = 1.0'

# %% [markdown]
# The nominal return rate on a principal $p_0$ and a payout of $p_1$ is calculated as follows: $\frac{p_1}{p_0} - 1$, real return rate can be calculated if all the cash flow is first adjusted for inflation, or alternatively, if the nominal return rate itself is discounted by the inflation rate, then the resulting value is the real return rate itself!

# %% [markdown]
# # Discounting and Compounding
#
# ## Asset Return
# Let's the $P_0$ is the price of an asset at the beginning of the period, and let $P_1$, and $D_1$ be the uncertain price and uncertain dividend at the end of the period. Then, the rate of return from the asset over the period is:
# $$ r = \frac{D_1 + P_1}{P_0} - 1 $$
#
# Thus, expected return $\overline{r} = E[r]$. Then, for a riskless asset, its return $r_F$, the **risk-free rate**, reflects time value of money. And for a risky asset, its return net of the risk-free rate, $r - r_F$ is the **excess return**. The **expected excess return** or the **risk-premium** on the asset is given by $\pi = \overline{r} - r_F$
#
# ### Historical nominal return and risk (1926-2018)
# | Asset  | Mean(%)  | SD (%) | Premium (%)  |
# |:-:|---|---|---|
# | T-Bills  |  3.4 | 3.1  |   |
# | Long term T-Bonds  |  5.9 |  9.8 | 2.5  |
# |  Long term C-Bonds | 6.3  |  8.4 | 2.9  |
# |  Large Stocks | 11.9 | 19.8 | 8.5 |
# |  Long term C-Bonds | 16.2 | 31.6 | 12.8  |
#
# ## Special Cash Flows
# Below we consider some special cash flows (some you might have already encountered in day-to-day life).
#
# ### Annuity
# Annuity is a constant cash flow for T periods (starting in period 1)
#
# > PV (Annuity) = $$ A * \frac{1}{r} [1 - \frac{1}{(1+r)^T)}]$$
#
# > FV (Annuity) = $$ (1+r) ^ T * PV (Annuity) $$
#
# * Q: An insurance company sells and annuity of \\$10,000 per year for 20 year, suppose that r=5%, then what should the company sell it for?

# %%
10000 * (1/0.05) * (1- 1/1.05**20)
# Out:
# 124622.10342539992

# %% [markdown]
# ### Annuity with Constant Growth Rate
# The PV of an annuity with constant growth rate g.
# > PV (Annuity with growth) = $A * \frac{1}{r-g} [1 - (\frac{1+g}{(1+r)})^T]$
#
# However, if the rate of growth is equal to the discount rate, then the formula simplifies as follows:
# > PV (Annuity) = $ \frac{T}{1+r} $
#
# Q: Suppose that you are now 30 and need $2 million at age 65 for your retirement. At the end of each year, you can save an amount that grows by 5% each year. How much should you start saving now, assuming that r=8%? (Ans: 6,472.96)

# %% [markdown]
# ### Perpetuity
#
# Perpetuity is a never ending cash flow.
#
# > PV(Perpetuity) = $\frac{A}{r}$
#
# > PV(Perpetuity with growth) = $\frac{A}{r-g}$
#
# Q: Super Growth Inc will pay an annual dividend next year of \\$3. The dividend is expected to grow 5% per year forever. For companies of this risk class, the expected rate of return is 10%. What should be Super Growth's price per share? (Ans: 60)
#
# ## Compounding
# Compounding is a simple process where a given principal is cumulatively incremented over a given time period. Interests is thus credited/charged over different periods. For instance, daily for bank accounts and credit card, monthly for loans and leases, and semi-annually for bonds. Therefore, for the same quoted interest rate, **the effective annual rates** may differ depending on how frequent interests are received/paid.
#
# Typical quoting conventions include:
# * Annual Percentage Rate (APR)
# * Periods of compounding
# * Interest per period (APR/k)

# %%
# compounding per year
compound = lambda apr, periods: (1+(apr/periods))**periods

apr, periods=0.1, 1
print(f'Annually compounding with rate: {apr*100}% gives {compound(apr, periods)}')
apr, periods=0.1, 12
print(f'Monthly compounding with rate: {apr*100}% gives {compound(apr, periods)}')
apr, periods=0.1, 365
print(f'Daily compounding with rate: {apr*100}% gives {compound(apr, periods)}')

print(f'It seems that the return converges to e^apr; {2.71828**apr}')
# Out:
# Annually compounding with rate: 10.0% gives 1.1
# Monthly compounding with rate: 10.0% gives 1.1047130674412968
# Daily compounding with rate: 10.0% gives 1.1051557816162325
# It seems that the return converges to e^apr; 1.105170843736028

# %% [markdown]
# The given equality summarizes both APR, and EAR
# > $ r_{EAR} = (1+ \frac{r_{APR}}{k})^k-1$

# %% [markdown]
# ## Mortgage Paymets
# Mortgages are common payments that rely on compounding.
#
# Suppose you bought a house for \\$500,000 with \$100,000 as down payment and financed the rest with a thirty year fixed rate mortgage at 8.5% APR, compounded monthly.

# %%
# Let M be the monthly payments, then
# 400,000 = sum of M/(1+monthly_rate)^t over next 360 months
total_mortgage_amount = 400_000
monthly_rate = 0.085/12
M = 400_000* monthly_rate/ (1-1/(1+monthly_rate)**360) ; print(M)
# Out:
# 3075.6539343373347

# %%
print(f"Total amount paid for a mortgage of {total_mortgage_amount} is {M*365}")

remaining_principal = total_mortgage_amount
for month in range(1,361):
    interest = monthly_rate*remaining_principal
    print(f'Month: {month} | Paym: {M:.2f} | Inter: {interest:.2f}', end='')
    principal_paid = M-interest
    remaining_principal = remaining_principal - principal_paid
    print(f'| P Paid: {principal_paid:.2f} | Rema Principal: {remaining_principal:.2f}')
# Out:
# Total amount paid for a mortgage of 400000 is 1122613.6860331271
# Month: 1 | Paym: 3075.65 | Inter: 2833.33| P Paid: 242.32 | Rema Principal: 399757.68
# Month: 2 | Paym: 3075.65 | Inter: 2831.62| P Paid: 244.04 | Rema Principal: 399513.64
# Month: 3 | Paym: 3075.65 | Inter: 2829.89| P Paid: 245.77 | Rema Principal: 399267.88
# Month: 4 | Paym: 3075.65 | Inter: 2828.15| P Paid: 247.51 | Rema Principal: 399020.37
# Month: 5 | Paym: 3075.65 | Inter: 2826.39| P Paid: 249.26 | Rema Principal: 398771.11
# Month: 6 | Paym: 3075.65 | Inter: 2824.63| P Paid: 251.03 | Rema Principal: 398520.09
# Month: 7 | Paym: 3075.65 | Inter: 2822.85| P Paid: 252.80 | Rema Principal: 398267.28
# Month: 8 | Paym: 3075.65 | Inter: 2821.06| P Paid: 254.59 | Rema Principal: 398012.69
# Month: 9 | Paym: 3075.65 | Inter: 2819.26| P Paid: 256.40 | Rema Principal: 397756.29
# Month: 10 | Paym: 3075.65 | Inter: 2817.44| P Paid: 258.21 | Rema Principal: 397498.08
# Month: 11 | Paym: 3075.65 | Inter: 2815.61| P Paid: 260.04 | Rema Principal: 397238.03
# Month: 12 | Paym: 3075.65 | Inter: 2813.77| P Paid: 261.88 | Rema Principal: 396976.15
# Month: 13 | Paym: 3075.65 | Inter: 2811.91| P Paid: 263.74 | Rema Principal: 396712.41
# Month: 14 | Paym: 3075.65 | Inter: 2810.05| P Paid: 265.61 | Rema Principal: 396446.80
# Month: 15 | Paym: 3075.65 | Inter: 2808.16| P Paid: 267.49 | Rema Principal: 396179.31
# Month: 16 | Paym: 3075.65 | Inter: 2806.27| P Paid: 269.38 | Rema Principal: 395909.93
# Month: 17 | Paym: 3075.65 | Inter: 2804.36| P Paid: 271.29 | Rema Principal: 395638.64
# Month: 18 | Paym: 3075.65 | Inter: 2802.44| P Paid: 273.21 | Rema Principal: 395365.42
# Month: 19 | Paym: 3075.65 | Inter: 2800.51| P Paid: 275.15 | Rema Principal: 395090.28
# Month: 20 | Paym: 3075.65 | Inter: 2798.56| P Paid: 277.10 | Rema Principal: 394813.18
# Month: 21 | Paym: 3075.65 | Inter: 2796.59| P Paid: 279.06 | Rema Principal: 394534.12
# Month: 22 | Paym: 3075.65 | Inter: 2794.62| P Paid: 281.04 | Rema Principal: 394253.08
# Month: 23 | Paym: 3075.65 | Inter: 2792.63| P Paid: 283.03 | Rema Principal: 393970.05
# Month: 24 | Paym: 3075.65 | Inter: 2790.62| P Paid: 285.03 | Rema Principal: 393685.02
# Month: 25 | Paym: 3075.65 | Inter: 2788.60| P Paid: 287.05 | Rema Principal: 393397.97
# Month: 26 | Paym: 3075.65 | Inter: 2786.57| P Paid: 289.08 | Rema Principal: 393108.88
# Month: 27 | Paym: 3075.65 | Inter: 2784.52| P Paid: 291.13 | Rema Principal: 392817.75
# Month: 28 | Paym: 3075.65 | Inter: 2782.46| P Paid: 293.19 | Rema Principal: 392524.55
# Month: 29 | Paym: 3075.65 | Inter: 2780.38| P Paid: 295.27 | Rema Principal: 392229.28
# Month: 30 | Paym: 3075.65 | Inter: 2778.29| P Paid: 297.36 | Rema Principal: 391931.92
# Month: 31 | Paym: 3075.65 | Inter: 2776.18| P Paid: 299.47 | Rema Principal: 391632.45
# Month: 32 | Paym: 3075.65 | Inter: 2774.06| P Paid: 301.59 | Rema Principal: 391330.86
# Month: 33 | Paym: 3075.65 | Inter: 2771.93| P Paid: 303.73 | Rema Principal: 391027.13
# Month: 34 | Paym: 3075.65 | Inter: 2769.78| P Paid: 305.88 | Rema Principal: 390721.25
# Month: 35 | Paym: 3075.65 | Inter: 2767.61| P Paid: 308.05 | Rema Principal: 390413.21
# Month: 36 | Paym: 3075.65 | Inter: 2765.43| P Paid: 310.23 | Rema Principal: 390102.98
# Month: 37 | Paym: 3075.65 | Inter: 2763.23| P Paid: 312.42 | Rema Principal: 389790.56
# Month: 38 | Paym: 3075.65 | Inter: 2761.02| P Paid: 314.64 | Rema Principal: 389475.92
# Month: 39 | Paym: 3075.65 | Inter: 2758.79| P Paid: 316.87 | Rema Principal: 389159.05
# Month: 40 | Paym: 3075.65 | Inter: 2756.54| P Paid: 319.11 | Rema Principal: 388839.94
# Month: 41 | Paym: 3075.65 | Inter: 2754.28| P Paid: 321.37 | Rema Principal: 388518.57
# Month: 42 | Paym: 3075.65 | Inter: 2752.01| P Paid: 323.65 | Rema Principal: 388194.93
# Month: 43 | Paym: 3075.65 | Inter: 2749.71| P Paid: 325.94 | Rema Principal: 387868.99
# Month: 44 | Paym: 3075.65 | Inter: 2747.41| P Paid: 328.25 | Rema Principal: 387540.74
# Month: 45 | Paym: 3075.65 | Inter: 2745.08| P Paid: 330.57 | Rema Principal: 387210.16
# Month: 46 | Paym: 3075.65 | Inter: 2742.74| P Paid: 332.92 | Rema Principal: 386877.25
# Month: 47 | Paym: 3075.65 | Inter: 2740.38| P Paid: 335.27 | Rema Principal: 386541.97
# Month: 48 | Paym: 3075.65 | Inter: 2738.01| P Paid: 337.65 | Rema Principal: 386204.33
# Month: 49 | Paym: 3075.65 | Inter: 2735.61| P Paid: 340.04 | Rema Principal: 385864.29
# Month: 50 | Paym: 3075.65 | Inter: 2733.21| P Paid: 342.45 | Rema Principal: 385521.84
# Month: 51 | Paym: 3075.65 | Inter: 2730.78| P Paid: 344.87 | Rema Principal: 385176.96
# Month: 52 | Paym: 3075.65 | Inter: 2728.34| P Paid: 347.32 | Rema Principal: 384829.65
# Month: 53 | Paym: 3075.65 | Inter: 2725.88| P Paid: 349.78 | Rema Principal: 384479.87
# Month: 54 | Paym: 3075.65 | Inter: 2723.40| P Paid: 352.25 | Rema Principal: 384127.61
# Month: 55 | Paym: 3075.65 | Inter: 2720.90| P Paid: 354.75 | Rema Principal: 383772.86
# Month: 56 | Paym: 3075.65 | Inter: 2718.39| P Paid: 357.26 | Rema Principal: 383415.60
# Month: 57 | Paym: 3075.65 | Inter: 2715.86| P Paid: 359.79 | Rema Principal: 383055.81
# Month: 58 | Paym: 3075.65 | Inter: 2713.31| P Paid: 362.34 | Rema Principal: 382693.47
# Month: 59 | Paym: 3075.65 | Inter: 2710.75| P Paid: 364.91 | Rema Principal: 382328.56
# Month: 60 | Paym: 3075.65 | Inter: 2708.16| P Paid: 367.49 | Rema Principal: 381961.06
# Month: 61 | Paym: 3075.65 | Inter: 2705.56| P Paid: 370.10 | Rema Principal: 381590.97
# Month: 62 | Paym: 3075.65 | Inter: 2702.94| P Paid: 372.72 | Rema Principal: 381218.25
# Month: 63 | Paym: 3075.65 | Inter: 2700.30| P Paid: 375.36 | Rema Principal: 380842.89
# Month: 64 | Paym: 3075.65 | Inter: 2697.64| P Paid: 378.02 | Rema Principal: 380464.87
# Month: 65 | Paym: 3075.65 | Inter: 2694.96| P Paid: 380.69 | Rema Principal: 380084.18
# Month: 66 | Paym: 3075.65 | Inter: 2692.26| P Paid: 383.39 | Rema Principal: 379700.79
# Month: 67 | Paym: 3075.65 | Inter: 2689.55| P Paid: 386.11 | Rema Principal: 379314.68
# Month: 68 | Paym: 3075.65 | Inter: 2686.81| P Paid: 388.84 | Rema Principal: 378925.84
# Month: 69 | Paym: 3075.65 | Inter: 2684.06| P Paid: 391.60 | Rema Principal: 378534.25
# Month: 70 | Paym: 3075.65 | Inter: 2681.28| P Paid: 394.37 | Rema Principal: 378139.88
# Month: 71 | Paym: 3075.65 | Inter: 2678.49| P Paid: 397.16 | Rema Principal: 377742.71
# Month: 72 | Paym: 3075.65 | Inter: 2675.68| P Paid: 399.98 | Rema Principal: 377342.74
# Month: 73 | Paym: 3075.65 | Inter: 2672.84| P Paid: 402.81 | Rema Principal: 376939.93
# Month: 74 | Paym: 3075.65 | Inter: 2669.99| P Paid: 405.66 | Rema Principal: 376534.26
# Month: 75 | Paym: 3075.65 | Inter: 2667.12| P Paid: 408.54 | Rema Principal: 376125.73
# Month: 76 | Paym: 3075.65 | Inter: 2664.22| P Paid: 411.43 | Rema Principal: 375714.30
# Month: 77 | Paym: 3075.65 | Inter: 2661.31| P Paid: 414.34 | Rema Principal: 375299.95
# Month: 78 | Paym: 3075.65 | Inter: 2658.37| P Paid: 417.28 | Rema Principal: 374882.67
# Month: 79 | Paym: 3075.65 | Inter: 2655.42| P Paid: 420.23 | Rema Principal: 374462.44
# Month: 80 | Paym: 3075.65 | Inter: 2652.44| P Paid: 423.21 | Rema Principal: 374039.23
# Month: 81 | Paym: 3075.65 | Inter: 2649.44| P Paid: 426.21 | Rema Principal: 373613.02
# Month: 82 | Paym: 3075.65 | Inter: 2646.43| P Paid: 429.23 | Rema Principal: 373183.79
# Month: 83 | Paym: 3075.65 | Inter: 2643.39| P Paid: 432.27 | Rema Principal: 372751.52
# Month: 84 | Paym: 3075.65 | Inter: 2640.32| P Paid: 435.33 | Rema Principal: 372316.19
# Month: 85 | Paym: 3075.65 | Inter: 2637.24| P Paid: 438.41 | Rema Principal: 371877.78
# Month: 86 | Paym: 3075.65 | Inter: 2634.13| P Paid: 441.52 | Rema Principal: 371436.26
# Month: 87 | Paym: 3075.65 | Inter: 2631.01| P Paid: 444.65 | Rema Principal: 370991.61
# Month: 88 | Paym: 3075.65 | Inter: 2627.86| P Paid: 447.80 | Rema Principal: 370543.81
# Month: 89 | Paym: 3075.65 | Inter: 2624.69| P Paid: 450.97 | Rema Principal: 370092.84
# Month: 90 | Paym: 3075.65 | Inter: 2621.49| P Paid: 454.16 | Rema Principal: 369638.68
# Month: 91 | Paym: 3075.65 | Inter: 2618.27| P Paid: 457.38 | Rema Principal: 369181.30
# Month: 92 | Paym: 3075.65 | Inter: 2615.03| P Paid: 460.62 | Rema Principal: 368720.68
# Month: 93 | Paym: 3075.65 | Inter: 2611.77| P Paid: 463.88 | Rema Principal: 368256.80
# Month: 94 | Paym: 3075.65 | Inter: 2608.49| P Paid: 467.17 | Rema Principal: 367789.63
# Month: 95 | Paym: 3075.65 | Inter: 2605.18| P Paid: 470.48 | Rema Principal: 367319.15
# Month: 96 | Paym: 3075.65 | Inter: 2601.84| P Paid: 473.81 | Rema Principal: 366845.34
# Month: 97 | Paym: 3075.65 | Inter: 2598.49| P Paid: 477.17 | Rema Principal: 366368.18
# Month: 98 | Paym: 3075.65 | Inter: 2595.11| P Paid: 480.55 | Rema Principal: 365887.63
# Month: 99 | Paym: 3075.65 | Inter: 2591.70| P Paid: 483.95 | Rema Principal: 365403.68
# Month: 100 | Paym: 3075.65 | Inter: 2588.28| P Paid: 487.38 | Rema Principal: 364916.30
# Month: 101 | Paym: 3075.65 | Inter: 2584.82| P Paid: 490.83 | Rema Principal: 364425.47
# Month: 102 | Paym: 3075.65 | Inter: 2581.35| P Paid: 494.31 | Rema Principal: 363931.17
# Month: 103 | Paym: 3075.65 | Inter: 2577.85| P Paid: 497.81 | Rema Principal: 363433.36
# Month: 104 | Paym: 3075.65 | Inter: 2574.32| P Paid: 501.33 | Rema Principal: 362932.02
# Month: 105 | Paym: 3075.65 | Inter: 2570.77| P Paid: 504.89 | Rema Principal: 362427.14
# Month: 106 | Paym: 3075.65 | Inter: 2567.19| P Paid: 508.46 | Rema Principal: 361918.68
# Month: 107 | Paym: 3075.65 | Inter: 2563.59| P Paid: 512.06 | Rema Principal: 361406.61
# Month: 108 | Paym: 3075.65 | Inter: 2559.96| P Paid: 515.69 | Rema Principal: 360890.92
# Month: 109 | Paym: 3075.65 | Inter: 2556.31| P Paid: 519.34 | Rema Principal: 360371.58
# Month: 110 | Paym: 3075.65 | Inter: 2552.63| P Paid: 523.02 | Rema Principal: 359848.56
# Month: 111 | Paym: 3075.65 | Inter: 2548.93| P Paid: 526.73 | Rema Principal: 359321.83
# Month: 112 | Paym: 3075.65 | Inter: 2545.20| P Paid: 530.46 | Rema Principal: 358791.37
# Month: 113 | Paym: 3075.65 | Inter: 2541.44| P Paid: 534.22 | Rema Principal: 358257.16
# Month: 114 | Paym: 3075.65 | Inter: 2537.65| P Paid: 538.00 | Rema Principal: 357719.16
# Month: 115 | Paym: 3075.65 | Inter: 2533.84| P Paid: 541.81 | Rema Principal: 357177.35
# Month: 116 | Paym: 3075.65 | Inter: 2530.01| P Paid: 545.65 | Rema Principal: 356631.70
# Month: 117 | Paym: 3075.65 | Inter: 2526.14| P Paid: 549.51 | Rema Principal: 356082.19
# Month: 118 | Paym: 3075.65 | Inter: 2522.25| P Paid: 553.41 | Rema Principal: 355528.78
# Month: 119 | Paym: 3075.65 | Inter: 2518.33| P Paid: 557.33 | Rema Principal: 354971.46
# Month: 120 | Paym: 3075.65 | Inter: 2514.38| P Paid: 561.27 | Rema Principal: 354410.19
# Month: 121 | Paym: 3075.65 | Inter: 2510.41| P Paid: 565.25 | Rema Principal: 353844.94
# Month: 122 | Paym: 3075.65 | Inter: 2506.40| P Paid: 569.25 | Rema Principal: 353275.69
# Month: 123 | Paym: 3075.65 | Inter: 2502.37| P Paid: 573.28 | Rema Principal: 352702.40
# Month: 124 | Paym: 3075.65 | Inter: 2498.31| P Paid: 577.35 | Rema Principal: 352125.06
# Month: 125 | Paym: 3075.65 | Inter: 2494.22| P Paid: 581.43 | Rema Principal: 351543.62
# Month: 126 | Paym: 3075.65 | Inter: 2490.10| P Paid: 585.55 | Rema Principal: 350958.07
# Month: 127 | Paym: 3075.65 | Inter: 2485.95| P Paid: 589.70 | Rema Principal: 350368.37
# Month: 128 | Paym: 3075.65 | Inter: 2481.78| P Paid: 593.88 | Rema Principal: 349774.49
# Month: 129 | Paym: 3075.65 | Inter: 2477.57| P Paid: 598.08 | Rema Principal: 349176.40
# Month: 130 | Paym: 3075.65 | Inter: 2473.33| P Paid: 602.32 | Rema Principal: 348574.08
# Month: 131 | Paym: 3075.65 | Inter: 2469.07| P Paid: 606.59 | Rema Principal: 347967.50
# Month: 132 | Paym: 3075.65 | Inter: 2464.77| P Paid: 610.88 | Rema Principal: 347356.61
# Month: 133 | Paym: 3075.65 | Inter: 2460.44| P Paid: 615.21 | Rema Principal: 346741.40
# Month: 134 | Paym: 3075.65 | Inter: 2456.08| P Paid: 619.57 | Rema Principal: 346121.83
# Month: 135 | Paym: 3075.65 | Inter: 2451.70| P Paid: 623.96 | Rema Principal: 345497.87
# Month: 136 | Paym: 3075.65 | Inter: 2447.28| P Paid: 628.38 | Rema Principal: 344869.50
# Month: 137 | Paym: 3075.65 | Inter: 2442.83| P Paid: 632.83 | Rema Principal: 344236.67
# Month: 138 | Paym: 3075.65 | Inter: 2438.34| P Paid: 637.31 | Rema Principal: 343599.36
# Month: 139 | Paym: 3075.65 | Inter: 2433.83| P Paid: 641.83 | Rema Principal: 342957.53
# Month: 140 | Paym: 3075.65 | Inter: 2429.28| P Paid: 646.37 | Rema Principal: 342311.16
# Month: 141 | Paym: 3075.65 | Inter: 2424.70| P Paid: 650.95 | Rema Principal: 341660.21
# Month: 142 | Paym: 3075.65 | Inter: 2420.09| P Paid: 655.56 | Rema Principal: 341004.65
# Month: 143 | Paym: 3075.65 | Inter: 2415.45| P Paid: 660.20 | Rema Principal: 340344.44
# Month: 144 | Paym: 3075.65 | Inter: 2410.77| P Paid: 664.88 | Rema Principal: 339679.56
# Month: 145 | Paym: 3075.65 | Inter: 2406.06| P Paid: 669.59 | Rema Principal: 339009.97
# Month: 146 | Paym: 3075.65 | Inter: 2401.32| P Paid: 674.33 | Rema Principal: 338335.64
# Month: 147 | Paym: 3075.65 | Inter: 2396.54| P Paid: 679.11 | Rema Principal: 337656.53
# Month: 148 | Paym: 3075.65 | Inter: 2391.73| P Paid: 683.92 | Rema Principal: 336972.61
# Month: 149 | Paym: 3075.65 | Inter: 2386.89| P Paid: 688.76 | Rema Principal: 336283.85
# Month: 150 | Paym: 3075.65 | Inter: 2382.01| P Paid: 693.64 | Rema Principal: 335590.20
# Month: 151 | Paym: 3075.65 | Inter: 2377.10| P Paid: 698.56 | Rema Principal: 334891.65
# Month: 152 | Paym: 3075.65 | Inter: 2372.15| P Paid: 703.50 | Rema Principal: 334188.14
# Month: 153 | Paym: 3075.65 | Inter: 2367.17| P Paid: 708.49 | Rema Principal: 333479.65
# Month: 154 | Paym: 3075.65 | Inter: 2362.15| P Paid: 713.51 | Rema Principal: 332766.15
# Month: 155 | Paym: 3075.65 | Inter: 2357.09| P Paid: 718.56 | Rema Principal: 332047.59
# Month: 156 | Paym: 3075.65 | Inter: 2352.00| P Paid: 723.65 | Rema Principal: 331323.94
# Month: 157 | Paym: 3075.65 | Inter: 2346.88| P Paid: 728.78 | Rema Principal: 330595.16
# Month: 158 | Paym: 3075.65 | Inter: 2341.72| P Paid: 733.94 | Rema Principal: 329861.22
# Month: 159 | Paym: 3075.65 | Inter: 2336.52| P Paid: 739.14 | Rema Principal: 329122.08
# Month: 160 | Paym: 3075.65 | Inter: 2331.28| P Paid: 744.37 | Rema Principal: 328377.71
# Month: 161 | Paym: 3075.65 | Inter: 2326.01| P Paid: 749.65 | Rema Principal: 327628.07
# Month: 162 | Paym: 3075.65 | Inter: 2320.70| P Paid: 754.96 | Rema Principal: 326873.11
# Month: 163 | Paym: 3075.65 | Inter: 2315.35| P Paid: 760.30 | Rema Principal: 326112.81
# Month: 164 | Paym: 3075.65 | Inter: 2309.97| P Paid: 765.69 | Rema Principal: 325347.12
# Month: 165 | Paym: 3075.65 | Inter: 2304.54| P Paid: 771.11 | Rema Principal: 324576.01
# Month: 166 | Paym: 3075.65 | Inter: 2299.08| P Paid: 776.57 | Rema Principal: 323799.44
# Month: 167 | Paym: 3075.65 | Inter: 2293.58| P Paid: 782.07 | Rema Principal: 323017.36
# Month: 168 | Paym: 3075.65 | Inter: 2288.04| P Paid: 787.61 | Rema Principal: 322229.75
# Month: 169 | Paym: 3075.65 | Inter: 2282.46| P Paid: 793.19 | Rema Principal: 321436.55
# Month: 170 | Paym: 3075.65 | Inter: 2276.84| P Paid: 798.81 | Rema Principal: 320637.74
# Month: 171 | Paym: 3075.65 | Inter: 2271.18| P Paid: 804.47 | Rema Principal: 319833.27
# Month: 172 | Paym: 3075.65 | Inter: 2265.49| P Paid: 810.17 | Rema Principal: 319023.10
# Month: 173 | Paym: 3075.65 | Inter: 2259.75| P Paid: 815.91 | Rema Principal: 318207.20
# Month: 174 | Paym: 3075.65 | Inter: 2253.97| P Paid: 821.69 | Rema Principal: 317385.51
# Month: 175 | Paym: 3075.65 | Inter: 2248.15| P Paid: 827.51 | Rema Principal: 316558.00
# Month: 176 | Paym: 3075.65 | Inter: 2242.29| P Paid: 833.37 | Rema Principal: 315724.64
# Month: 177 | Paym: 3075.65 | Inter: 2236.38| P Paid: 839.27 | Rema Principal: 314885.36
# Month: 178 | Paym: 3075.65 | Inter: 2230.44| P Paid: 845.22 | Rema Principal: 314040.15
# Month: 179 | Paym: 3075.65 | Inter: 2224.45| P Paid: 851.20 | Rema Principal: 313188.95
# Month: 180 | Paym: 3075.65 | Inter: 2218.42| P Paid: 857.23 | Rema Principal: 312331.71
# Month: 181 | Paym: 3075.65 | Inter: 2212.35| P Paid: 863.30 | Rema Principal: 311468.41
# Month: 182 | Paym: 3075.65 | Inter: 2206.23| P Paid: 869.42 | Rema Principal: 310598.99
# Month: 183 | Paym: 3075.65 | Inter: 2200.08| P Paid: 875.58 | Rema Principal: 309723.41
# Month: 184 | Paym: 3075.65 | Inter: 2193.87| P Paid: 881.78 | Rema Principal: 308841.63
# Month: 185 | Paym: 3075.65 | Inter: 2187.63| P Paid: 888.03 | Rema Principal: 307953.61
# Month: 186 | Paym: 3075.65 | Inter: 2181.34| P Paid: 894.32 | Rema Principal: 307059.29
# Month: 187 | Paym: 3075.65 | Inter: 2175.00| P Paid: 900.65 | Rema Principal: 306158.64
# Month: 188 | Paym: 3075.65 | Inter: 2168.62| P Paid: 907.03 | Rema Principal: 305251.61
# Month: 189 | Paym: 3075.65 | Inter: 2162.20| P Paid: 913.46 | Rema Principal: 304338.15
# Month: 190 | Paym: 3075.65 | Inter: 2155.73| P Paid: 919.93 | Rema Principal: 303418.23
# Month: 191 | Paym: 3075.65 | Inter: 2149.21| P Paid: 926.44 | Rema Principal: 302491.79
# Month: 192 | Paym: 3075.65 | Inter: 2142.65| P Paid: 933.00 | Rema Principal: 301558.78
# Month: 193 | Paym: 3075.65 | Inter: 2136.04| P Paid: 939.61 | Rema Principal: 300619.17
# Month: 194 | Paym: 3075.65 | Inter: 2129.39| P Paid: 946.27 | Rema Principal: 299672.90
# Month: 195 | Paym: 3075.65 | Inter: 2122.68| P Paid: 952.97 | Rema Principal: 298719.93
# Month: 196 | Paym: 3075.65 | Inter: 2115.93| P Paid: 959.72 | Rema Principal: 297760.21
# Month: 197 | Paym: 3075.65 | Inter: 2109.13| P Paid: 966.52 | Rema Principal: 296793.69
# Month: 198 | Paym: 3075.65 | Inter: 2102.29| P Paid: 973.37 | Rema Principal: 295820.33
# Month: 199 | Paym: 3075.65 | Inter: 2095.39| P Paid: 980.26 | Rema Principal: 294840.07
# Month: 200 | Paym: 3075.65 | Inter: 2088.45| P Paid: 987.20 | Rema Principal: 293852.86
# Month: 201 | Paym: 3075.65 | Inter: 2081.46| P Paid: 994.20 | Rema Principal: 292858.67
# Month: 202 | Paym: 3075.65 | Inter: 2074.42| P Paid: 1001.24 | Rema Principal: 291857.43
# Month: 203 | Paym: 3075.65 | Inter: 2067.32| P Paid: 1008.33 | Rema Principal: 290849.10
# Month: 204 | Paym: 3075.65 | Inter: 2060.18| P Paid: 1015.47 | Rema Principal: 289833.63
# Month: 205 | Paym: 3075.65 | Inter: 2052.99| P Paid: 1022.67 | Rema Principal: 288810.96
# Month: 206 | Paym: 3075.65 | Inter: 2045.74| P Paid: 1029.91 | Rema Principal: 287781.05
# Month: 207 | Paym: 3075.65 | Inter: 2038.45| P Paid: 1037.20 | Rema Principal: 286743.85
# Month: 208 | Paym: 3075.65 | Inter: 2031.10| P Paid: 1044.55 | Rema Principal: 285699.29
# Month: 209 | Paym: 3075.65 | Inter: 2023.70| P Paid: 1051.95 | Rema Principal: 284647.34
# Month: 210 | Paym: 3075.65 | Inter: 2016.25| P Paid: 1059.40 | Rema Principal: 283587.94
# Month: 211 | Paym: 3075.65 | Inter: 2008.75| P Paid: 1066.91 | Rema Principal: 282521.04
# Month: 212 | Paym: 3075.65 | Inter: 2001.19| P Paid: 1074.46 | Rema Principal: 281446.57
# Month: 213 | Paym: 3075.65 | Inter: 1993.58| P Paid: 1082.07 | Rema Principal: 280364.50
# Month: 214 | Paym: 3075.65 | Inter: 1985.92| P Paid: 1089.74 | Rema Principal: 279274.76
# Month: 215 | Paym: 3075.65 | Inter: 1978.20| P Paid: 1097.46 | Rema Principal: 278177.30
# Month: 216 | Paym: 3075.65 | Inter: 1970.42| P Paid: 1105.23 | Rema Principal: 277072.07
# Month: 217 | Paym: 3075.65 | Inter: 1962.59| P Paid: 1113.06 | Rema Principal: 275959.01
# Month: 218 | Paym: 3075.65 | Inter: 1954.71| P Paid: 1120.94 | Rema Principal: 274838.07
# Month: 219 | Paym: 3075.65 | Inter: 1946.77| P Paid: 1128.88 | Rema Principal: 273709.18
# Month: 220 | Paym: 3075.65 | Inter: 1938.77| P Paid: 1136.88 | Rema Principal: 272572.30
# Month: 221 | Paym: 3075.65 | Inter: 1930.72| P Paid: 1144.93 | Rema Principal: 271427.37
# Month: 222 | Paym: 3075.65 | Inter: 1922.61| P Paid: 1153.04 | Rema Principal: 270274.32
# Month: 223 | Paym: 3075.65 | Inter: 1914.44| P Paid: 1161.21 | Rema Principal: 269113.11
# Month: 224 | Paym: 3075.65 | Inter: 1906.22| P Paid: 1169.44 | Rema Principal: 267943.68
# Month: 225 | Paym: 3075.65 | Inter: 1897.93| P Paid: 1177.72 | Rema Principal: 266765.96
# Month: 226 | Paym: 3075.65 | Inter: 1889.59| P Paid: 1186.06 | Rema Principal: 265579.90
# Month: 227 | Paym: 3075.65 | Inter: 1881.19| P Paid: 1194.46 | Rema Principal: 264385.43
# Month: 228 | Paym: 3075.65 | Inter: 1872.73| P Paid: 1202.92 | Rema Principal: 263182.51
# Month: 229 | Paym: 3075.65 | Inter: 1864.21| P Paid: 1211.44 | Rema Principal: 261971.06
# Month: 230 | Paym: 3075.65 | Inter: 1855.63| P Paid: 1220.03 | Rema Principal: 260751.04
# Month: 231 | Paym: 3075.65 | Inter: 1846.99| P Paid: 1228.67 | Rema Principal: 259522.37
# Month: 232 | Paym: 3075.65 | Inter: 1838.28| P Paid: 1237.37 | Rema Principal: 258285.00
# Month: 233 | Paym: 3075.65 | Inter: 1829.52| P Paid: 1246.14 | Rema Principal: 257038.87
# Month: 234 | Paym: 3075.65 | Inter: 1820.69| P Paid: 1254.96 | Rema Principal: 255783.90
# Month: 235 | Paym: 3075.65 | Inter: 1811.80| P Paid: 1263.85 | Rema Principal: 254520.05
# Month: 236 | Paym: 3075.65 | Inter: 1802.85| P Paid: 1272.80 | Rema Principal: 253247.25
# Month: 237 | Paym: 3075.65 | Inter: 1793.83| P Paid: 1281.82 | Rema Principal: 251965.43
# Month: 238 | Paym: 3075.65 | Inter: 1784.76| P Paid: 1290.90 | Rema Principal: 250674.53
# Month: 239 | Paym: 3075.65 | Inter: 1775.61| P Paid: 1300.04 | Rema Principal: 249374.49
# Month: 240 | Paym: 3075.65 | Inter: 1766.40| P Paid: 1309.25 | Rema Principal: 248065.24
# Month: 241 | Paym: 3075.65 | Inter: 1757.13| P Paid: 1318.53 | Rema Principal: 246746.71
# Month: 242 | Paym: 3075.65 | Inter: 1747.79| P Paid: 1327.86 | Rema Principal: 245418.85
# Month: 243 | Paym: 3075.65 | Inter: 1738.38| P Paid: 1337.27 | Rema Principal: 244081.58
# Month: 244 | Paym: 3075.65 | Inter: 1728.91| P Paid: 1346.74 | Rema Principal: 242734.83
# Month: 245 | Paym: 3075.65 | Inter: 1719.37| P Paid: 1356.28 | Rema Principal: 241378.55
# Month: 246 | Paym: 3075.65 | Inter: 1709.76| P Paid: 1365.89 | Rema Principal: 240012.66
# Month: 247 | Paym: 3075.65 | Inter: 1700.09| P Paid: 1375.56 | Rema Principal: 238637.10
# Month: 248 | Paym: 3075.65 | Inter: 1690.35| P Paid: 1385.31 | Rema Principal: 237251.79
# Month: 249 | Paym: 3075.65 | Inter: 1680.53| P Paid: 1395.12 | Rema Principal: 235856.67
# Month: 250 | Paym: 3075.65 | Inter: 1670.65| P Paid: 1405.00 | Rema Principal: 234451.67
# Month: 251 | Paym: 3075.65 | Inter: 1660.70| P Paid: 1414.95 | Rema Principal: 233036.71
# Month: 252 | Paym: 3075.65 | Inter: 1650.68| P Paid: 1424.98 | Rema Principal: 231611.74
# Month: 253 | Paym: 3075.65 | Inter: 1640.58| P Paid: 1435.07 | Rema Principal: 230176.67
# Month: 254 | Paym: 3075.65 | Inter: 1630.42| P Paid: 1445.24 | Rema Principal: 228731.43
# Month: 255 | Paym: 3075.65 | Inter: 1620.18| P Paid: 1455.47 | Rema Principal: 227275.96
# Month: 256 | Paym: 3075.65 | Inter: 1609.87| P Paid: 1465.78 | Rema Principal: 225810.17
# Month: 257 | Paym: 3075.65 | Inter: 1599.49| P Paid: 1476.17 | Rema Principal: 224334.01
# Month: 258 | Paym: 3075.65 | Inter: 1589.03| P Paid: 1486.62 | Rema Principal: 222847.39
# Month: 259 | Paym: 3075.65 | Inter: 1578.50| P Paid: 1497.15 | Rema Principal: 221350.24
# Month: 260 | Paym: 3075.65 | Inter: 1567.90| P Paid: 1507.76 | Rema Principal: 219842.48
# Month: 261 | Paym: 3075.65 | Inter: 1557.22| P Paid: 1518.44 | Rema Principal: 218324.04
# Month: 262 | Paym: 3075.65 | Inter: 1546.46| P Paid: 1529.19 | Rema Principal: 216794.85
# Month: 263 | Paym: 3075.65 | Inter: 1535.63| P Paid: 1540.02 | Rema Principal: 215254.83
# Month: 264 | Paym: 3075.65 | Inter: 1524.72| P Paid: 1550.93 | Rema Principal: 213703.89
# Month: 265 | Paym: 3075.65 | Inter: 1513.74| P Paid: 1561.92 | Rema Principal: 212141.98
# Month: 266 | Paym: 3075.65 | Inter: 1502.67| P Paid: 1572.98 | Rema Principal: 210569.00
# Month: 267 | Paym: 3075.65 | Inter: 1491.53| P Paid: 1584.12 | Rema Principal: 208984.87
# Month: 268 | Paym: 3075.65 | Inter: 1480.31| P Paid: 1595.34 | Rema Principal: 207389.53
# Month: 269 | Paym: 3075.65 | Inter: 1469.01| P Paid: 1606.64 | Rema Principal: 205782.88
# Month: 270 | Paym: 3075.65 | Inter: 1457.63| P Paid: 1618.03 | Rema Principal: 204164.86
# Month: 271 | Paym: 3075.65 | Inter: 1446.17| P Paid: 1629.49 | Rema Principal: 202535.37
# Month: 272 | Paym: 3075.65 | Inter: 1434.63| P Paid: 1641.03 | Rema Principal: 200894.34
# Month: 273 | Paym: 3075.65 | Inter: 1423.00| P Paid: 1652.65 | Rema Principal: 199241.69
# Month: 274 | Paym: 3075.65 | Inter: 1411.30| P Paid: 1664.36 | Rema Principal: 197577.33
# Month: 275 | Paym: 3075.65 | Inter: 1399.51| P Paid: 1676.15 | Rema Principal: 195901.18
# Month: 276 | Paym: 3075.65 | Inter: 1387.63| P Paid: 1688.02 | Rema Principal: 194213.16
# Month: 277 | Paym: 3075.65 | Inter: 1375.68| P Paid: 1699.98 | Rema Principal: 192513.19
# Month: 278 | Paym: 3075.65 | Inter: 1363.64| P Paid: 1712.02 | Rema Principal: 190801.17
# Month: 279 | Paym: 3075.65 | Inter: 1351.51| P Paid: 1724.15 | Rema Principal: 189077.02
# Month: 280 | Paym: 3075.65 | Inter: 1339.30| P Paid: 1736.36 | Rema Principal: 187340.66
# Month: 281 | Paym: 3075.65 | Inter: 1327.00| P Paid: 1748.66 | Rema Principal: 185592.01
# Month: 282 | Paym: 3075.65 | Inter: 1314.61| P Paid: 1761.04 | Rema Principal: 183830.96
# Month: 283 | Paym: 3075.65 | Inter: 1302.14| P Paid: 1773.52 | Rema Principal: 182057.44
# Month: 284 | Paym: 3075.65 | Inter: 1289.57| P Paid: 1786.08 | Rema Principal: 180271.36
# Month: 285 | Paym: 3075.65 | Inter: 1276.92| P Paid: 1798.73 | Rema Principal: 178472.63
# Month: 286 | Paym: 3075.65 | Inter: 1264.18| P Paid: 1811.47 | Rema Principal: 176661.16
# Month: 287 | Paym: 3075.65 | Inter: 1251.35| P Paid: 1824.30 | Rema Principal: 174836.85
# Month: 288 | Paym: 3075.65 | Inter: 1238.43| P Paid: 1837.23 | Rema Principal: 172999.63
# Month: 289 | Paym: 3075.65 | Inter: 1225.41| P Paid: 1850.24 | Rema Principal: 171149.39
# Month: 290 | Paym: 3075.65 | Inter: 1212.31| P Paid: 1863.35 | Rema Principal: 169286.04
# Month: 291 | Paym: 3075.65 | Inter: 1199.11| P Paid: 1876.54 | Rema Principal: 167409.50
# Month: 292 | Paym: 3075.65 | Inter: 1185.82| P Paid: 1889.84 | Rema Principal: 165519.66
# Month: 293 | Paym: 3075.65 | Inter: 1172.43| P Paid: 1903.22 | Rema Principal: 163616.44
# Month: 294 | Paym: 3075.65 | Inter: 1158.95| P Paid: 1916.70 | Rema Principal: 161699.73
# Month: 295 | Paym: 3075.65 | Inter: 1145.37| P Paid: 1930.28 | Rema Principal: 159769.45
# Month: 296 | Paym: 3075.65 | Inter: 1131.70| P Paid: 1943.95 | Rema Principal: 157825.50
# Month: 297 | Paym: 3075.65 | Inter: 1117.93| P Paid: 1957.72 | Rema Principal: 155867.78
# Month: 298 | Paym: 3075.65 | Inter: 1104.06| P Paid: 1971.59 | Rema Principal: 153896.19
# Month: 299 | Paym: 3075.65 | Inter: 1090.10| P Paid: 1985.56 | Rema Principal: 151910.63
# Month: 300 | Paym: 3075.65 | Inter: 1076.03| P Paid: 1999.62 | Rema Principal: 149911.01
# Month: 301 | Paym: 3075.65 | Inter: 1061.87| P Paid: 2013.78 | Rema Principal: 147897.23
# Month: 302 | Paym: 3075.65 | Inter: 1047.61| P Paid: 2028.05 | Rema Principal: 145869.18
# Month: 303 | Paym: 3075.65 | Inter: 1033.24| P Paid: 2042.41 | Rema Principal: 143826.76
# Month: 304 | Paym: 3075.65 | Inter: 1018.77| P Paid: 2056.88 | Rema Principal: 141769.88
# Month: 305 | Paym: 3075.65 | Inter: 1004.20| P Paid: 2071.45 | Rema Principal: 139698.43
# Month: 306 | Paym: 3075.65 | Inter: 989.53| P Paid: 2086.12 | Rema Principal: 137612.31
# Month: 307 | Paym: 3075.65 | Inter: 974.75| P Paid: 2100.90 | Rema Principal: 135511.41
# Month: 308 | Paym: 3075.65 | Inter: 959.87| P Paid: 2115.78 | Rema Principal: 133395.63
# Month: 309 | Paym: 3075.65 | Inter: 944.89| P Paid: 2130.77 | Rema Principal: 131264.86
# Month: 310 | Paym: 3075.65 | Inter: 929.79| P Paid: 2145.86 | Rema Principal: 129119.00
# Month: 311 | Paym: 3075.65 | Inter: 914.59| P Paid: 2161.06 | Rema Principal: 126957.94
# Month: 312 | Paym: 3075.65 | Inter: 899.29| P Paid: 2176.37 | Rema Principal: 124781.57
# Month: 313 | Paym: 3075.65 | Inter: 883.87| P Paid: 2191.78 | Rema Principal: 122589.78
# Month: 314 | Paym: 3075.65 | Inter: 868.34| P Paid: 2207.31 | Rema Principal: 120382.47
# Month: 315 | Paym: 3075.65 | Inter: 852.71| P Paid: 2222.94 | Rema Principal: 118159.53
# Month: 316 | Paym: 3075.65 | Inter: 836.96| P Paid: 2238.69 | Rema Principal: 115920.84
# Month: 317 | Paym: 3075.65 | Inter: 821.11| P Paid: 2254.55 | Rema Principal: 113666.29
# Month: 318 | Paym: 3075.65 | Inter: 805.14| P Paid: 2270.52 | Rema Principal: 111395.77
# Month: 319 | Paym: 3075.65 | Inter: 789.05| P Paid: 2286.60 | Rema Principal: 109109.17
# Month: 320 | Paym: 3075.65 | Inter: 772.86| P Paid: 2302.80 | Rema Principal: 106806.37
# Month: 321 | Paym: 3075.65 | Inter: 756.55| P Paid: 2319.11 | Rema Principal: 104487.27
# Month: 322 | Paym: 3075.65 | Inter: 740.12| P Paid: 2335.54 | Rema Principal: 102151.73
# Month: 323 | Paym: 3075.65 | Inter: 723.57| P Paid: 2352.08 | Rema Principal: 99799.65
# Month: 324 | Paym: 3075.65 | Inter: 706.91| P Paid: 2368.74 | Rema Principal: 97430.91
# Month: 325 | Paym: 3075.65 | Inter: 690.14| P Paid: 2385.52 | Rema Principal: 95045.39
# Month: 326 | Paym: 3075.65 | Inter: 673.24| P Paid: 2402.42 | Rema Principal: 92642.98
# Month: 327 | Paym: 3075.65 | Inter: 656.22| P Paid: 2419.43 | Rema Principal: 90223.54
# Month: 328 | Paym: 3075.65 | Inter: 639.08| P Paid: 2436.57 | Rema Principal: 87786.97
# Month: 329 | Paym: 3075.65 | Inter: 621.82| P Paid: 2453.83 | Rema Principal: 85333.14
# Month: 330 | Paym: 3075.65 | Inter: 604.44| P Paid: 2471.21 | Rema Principal: 82861.93
# Month: 331 | Paym: 3075.65 | Inter: 586.94| P Paid: 2488.72 | Rema Principal: 80373.22
# Month: 332 | Paym: 3075.65 | Inter: 569.31| P Paid: 2506.34 | Rema Principal: 77866.87
# Month: 333 | Paym: 3075.65 | Inter: 551.56| P Paid: 2524.10 | Rema Principal: 75342.78
# Month: 334 | Paym: 3075.65 | Inter: 533.68| P Paid: 2541.98 | Rema Principal: 72800.80
# Month: 335 | Paym: 3075.65 | Inter: 515.67| P Paid: 2559.98 | Rema Principal: 70240.82
# Month: 336 | Paym: 3075.65 | Inter: 497.54| P Paid: 2578.11 | Rema Principal: 67662.71
# Month: 337 | Paym: 3075.65 | Inter: 479.28| P Paid: 2596.38 | Rema Principal: 65066.33
# Month: 338 | Paym: 3075.65 | Inter: 460.89| P Paid: 2614.77 | Rema Principal: 62451.56
# Month: 339 | Paym: 3075.65 | Inter: 442.37| P Paid: 2633.29 | Rema Principal: 59818.27
# Month: 340 | Paym: 3075.65 | Inter: 423.71| P Paid: 2651.94 | Rema Principal: 57166.33
# Month: 341 | Paym: 3075.65 | Inter: 404.93| P Paid: 2670.73 | Rema Principal: 54495.61
# Month: 342 | Paym: 3075.65 | Inter: 386.01| P Paid: 2689.64 | Rema Principal: 51805.96
# Month: 343 | Paym: 3075.65 | Inter: 366.96| P Paid: 2708.70 | Rema Principal: 49097.27
# Month: 344 | Paym: 3075.65 | Inter: 347.77| P Paid: 2727.88 | Rema Principal: 46369.39
# Month: 345 | Paym: 3075.65 | Inter: 328.45| P Paid: 2747.20 | Rema Principal: 43622.18
# Month: 346 | Paym: 3075.65 | Inter: 308.99| P Paid: 2766.66 | Rema Principal: 40855.52
# Month: 347 | Paym: 3075.65 | Inter: 289.39| P Paid: 2786.26 | Rema Principal: 38069.26
# Month: 348 | Paym: 3075.65 | Inter: 269.66| P Paid: 2806.00 | Rema Principal: 35263.26
# Month: 349 | Paym: 3075.65 | Inter: 249.78| P Paid: 2825.87 | Rema Principal: 32437.39
# Month: 350 | Paym: 3075.65 | Inter: 229.76| P Paid: 2845.89 | Rema Principal: 29591.50
# Month: 351 | Paym: 3075.65 | Inter: 209.61| P Paid: 2866.05 | Rema Principal: 26725.45
# Month: 352 | Paym: 3075.65 | Inter: 189.31| P Paid: 2886.35 | Rema Principal: 23839.10
# Month: 353 | Paym: 3075.65 | Inter: 168.86| P Paid: 2906.79 | Rema Principal: 20932.31
# Month: 354 | Paym: 3075.65 | Inter: 148.27| P Paid: 2927.38 | Rema Principal: 18004.93
# Month: 355 | Paym: 3075.65 | Inter: 127.53| P Paid: 2948.12 | Rema Principal: 15056.81
# Month: 356 | Paym: 3075.65 | Inter: 106.65| P Paid: 2969.00 | Rema Principal: 12087.81
# Month: 357 | Paym: 3075.65 | Inter: 85.62| P Paid: 2990.03 | Rema Principal: 9097.77
# Month: 358 | Paym: 3075.65 | Inter: 64.44| P Paid: 3011.21 | Rema Principal: 6086.56
# Month: 359 | Paym: 3075.65 | Inter: 43.11| P Paid: 3032.54 | Rema Principal: 3054.02
# Month: 360 | Paym: 3075.65 | Inter: 21.63| P Paid: 3054.02 | Rema Principal: -0.00

# %% [markdown]
# ## Extensions
# Similarly, we can extrapolate the present value of Expected return of cash any cash flow, such as taxes, currencies, forecasting cash flows.

# %% [markdown]
# # Fixed Income Securities
#
# ## Yield Curve
# Suppose you have a 3-year bond with principal \\$1000 and an annual coupon payment of 5%.

# %%
[50, 50, 50+1000] # the cash flow
# Out:
# [50, 50, 150]

# %% [markdown]
# The time value of money in the market can be captured in different forms:
# * Spot interest rates
# * prices of discount bonds (zero-coupon bonds)
# * Prices of coupon bonds
#
# **Spot interest rate** is the current (annualized) interest rate ($r_t$) for maturity date $t$. Yield curve, then, is the set of spot itnerest rates for different maturities.

# %% [markdown]
# ## Discount vs Coupon Bonds
# The current price of a discount bond maturing at time $t$ and its relationship with rate $r_t$ is given by
# $B_t = \frac{1}{(1+r_t)^t}$
#
# {TODO: Add example}
#
# ## Relative Bond Valuation
# Suppose there are three bonds A, B, and C, with cash flows as follows:
#
# | Bond | t = 1 | t = 2 | t = 3 | Price |
# | ---- | ----- | ----- | ----- | ----- |
# | A | 100 | 0 | 0 | 96 |
# | B | 5| 105 | 0| 99.3 |
# | C | 10 | 10 | 110 | 108.8 |
#
# Now, consider a 3-year discount bond with the face value of \\$100, traded at \\$84. Is this bond fairly priced? If not, then build an arbitrage strategy.
#
# Let's say the price of a discount bond in year 1 $P_1$, in year 2 $P_2$, and in year 3 it's $P_3$. Then we solve the system of linear equations:
# $$ 100 * P_1 + 0 * P_2 + 0 * P_3 = 96 $$
# $$ 5 * P_1 + 105 * P_2 + 0 * P_3 = 99.3 $$
# $$ 10 * P_1 + 10 * P_2 + 110 * P_3 = 108.8 $$
#
# Upon solving, we find $P_1$ = 0.96, $P_2$ = 0.90, $P_3$ = 0.82, and we find that the implied price of D is inconsistent. (It should be \\$82).
#
# ## Arbitrage Strategy
# In order to construct an arbitrage opportunity, we construct a portfolio such the the shares of bonds A, B, C, and D give a cash-flow of \\$1 at time 0, and nothing in periods 1, 2, and 3. Let's solve it!

# %%
import numpy.linalg as lin
arbitrage_portfolio = lin.solve([[-96, -99.3, -108.8, -84],
           [100, 5, 10, 0],
           [0, 105, 10, 0],
           [0, 0, 110, 100]], [1, 0, 0, 0])

print(list(zip([char for char in 'ABCD'], arbitrage_portfolio)))
# Out:
# [('A', -0.043290043290042976), ('B', -0.04329004329004298), ('C', 0.4545454545454513), ('D', -0.49999999999999645)]

# %% [markdown]
# ## Yield to Maturity
# Yield to maturity is a convention for quoting prices and is a function of interest rates of various maturities. It can be seen as the rate $y$ that solves the PV calculation of bonds without relying on separate spot rate values. {TODO: relationship between spot rates and ytm}.
#
# ## YTM vs Coupon Rate
# Bond price is inversely related to YTM. A bond sells at **par** only if its coupon rate equals the YTM. If it's lower, then the bond is selling at a **discount**, otherwise, it is selling at a **premium**.
#
#
# ## Bond Duration
# Suppose bond price is \\$90 at yield - 0.05. As the yield change to 0.04, bond price rises to \\$91.8, then the relative price change is (91.8-90)/90 = 0.02. This gives us the risk measure (normalized by the change in the yield) as $\frac{0.02}{0.05-0.04} = 2$ We can do better by instead relying on derivatives to get infinitesimal granularity.
#
# > Bond Risk = $- \frac{1}{B} \frac{dB}{dy}$
#
#
# ### Modified Duration
# For a discount bond, $B_t = (1+y)^{-t}$, hence (note how actual time is related to the physical timing of the cash flow) $$ MD(B_{t}) = -\frac{1}{B_t} \frac{dB_t}{dy} = \frac{t}{1+y}$$
#
# ### Macaulay Duration
# **Macalulay Duration** is the weighted average term to maturity. Intuitively, it is the center of gravity of paymnet tensors. It is proportional to Modified duration as follows: $$ MD = \frac{D}{1+y}$$
#
# ### Duration and Convexity
# If duration gives the slope of the price/yield curve, then convexity gives the curvature. **Convexity (CX)** measures the curvature of the bond price as a function of the yield as follows: $$ CX = \frac{1}{2} \frac{1}{B} \frac {d^2 B}{dy^2}
